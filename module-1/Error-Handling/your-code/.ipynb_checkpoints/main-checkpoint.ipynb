# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Libraries
import math

# %% [markdown]
# # Challenge 1 - Handling Errors Using `if` Statements
#
# In many cases, we are able to identify issues that may come up in our code and handle those handlful of issues with an `if` statment. Sometimes we would like to handle different types of inputs and are aware that later in the code, we will have to write two different branches of code for the two different cases we allowed in the beginning.
#
# In the 3 cells below, add an `if` statment that will handle both types of input allowed in the functions.

# %%
# Modify the code below to handle positive and negative numbers by adding an if statement and performing a transformation:

def sqrt_for_all(x):
    """
    This function will take any real number and 
    return the square root of its magnitude.
    
    Input: Real number
    Output: Real number
    
    Sample Input: -4
    Sample Output: 2.0
    """
    if x<0:
        x= -x
        
    return math.sqrt(x)

sqrt_for_all(-1)
# Out:
# 1.0

# %%
# Modify the code below to handle zero as well. In the case of zero, return zero

def divide(x, y):
    """
    This function will take any two real numbers 
    and return their quotient. 
    If the denominator is zero, we return zero.
    
    Input: Real number
    Output: Real number
    
    Sample Input: 5, 1
    Sample Output: 5.0
    """
    if y == 0:
        return 0
    else:
        return x / y

divide(5, 0)
# Out:
# 0

# %%
# Modify the function below that it will take either an number and a list or two numbers. 
# If we take two numbers, add them together and return a list of length 1. 
# Otherwise, add the number to every element of the list and return the resulting list

def add_elements(a, l):
    """
    This function takes either two numbers or a list and a number 
    and adds the number to all elements of the list.
    If the function only takes two numbers, it returns a list 
    of length one that is the sum of the numbers.
    
    Input: number and list or two numbers
    Output: list
    
    Sample Input: 5, 6
    Sample Output: [11]
    """
    if type(l) != list:
        return [a+l]
    else:
        return [a + element for element in l]
        
add_elements(5, 6)
# Out:
# [11]

# %% [markdown]
# # Challenge 2 - Fixing Errors to Get Code to Run
#
# Sometimes the error is not caused by the input but by the code itself. In the 2 following cells below, examine the error and correct the code to avoid the error.

# %%
# Modify the code below:

l = [1,2,3,4]

sum([element + 1 for element in l])
# Out:
# 14

# %%
# Modify the code below:

l = [1,2,3,4]

for element in l:
    print("The current element in the loop is " + str(element))
# Out:
# The current element in the loop is 1
# The current element in the loop is 2
# The current element in the loop is 3
# The current element in the loop is 4

# %% [markdown]
# # Bonus Challenge - Raise Errors on Your Own
#
# There are cases where you need to alert your users of a problem even if the input will not immediately produce an error. In these cases you may want to throw an error yourself to bring attention to the problem. In the 2 cells below, write the functions as directed and add the appropriate errors using the `raise` clause. Make sure to add a meaningful error message.

# %%
def log_square(x):
    """
    This function takes a numeric value and returns the 
    natural log of the square of the number.
    The function raises an error if the number is equal to zero.
    Use the math.log function in this funtion.
    
    Input: Real number
    Output: Real number or error
    
    Sample Input: 5
    Sample Output: 3.21887
    """
    
    # Your code here:
    if x == 0 :
        raise ValueError ("The number should not be equal to zero")
    else:
        return math.log(x**2)
    
print(log_square(5))
print(log_square(0))
# Out:
# 3.2188758248682006
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e099aff78d2b> in <module>
#      20
#      21 print(log_square(5))
# ---> 22 print(log_square(0))
#
# <ipython-input-23-e099aff78d2b> in log_square(x)
#      15     # Your code here:
#      16     if x == 0 :
# ---> 17         raise ValueError ("The number should not be equal to zero")
#      18     else:
#      19         return math.log(x**2)
#
# ValueError: The number should not be equal to zero

# %%
import re

def check_capital(x):
    """
    This function returns true if the string contains 
    at least one capital letter and throws an error otherwise.
    
    Input: String
    Output: Bool or error message
    
    Sample Input: 'John'
    Sample Output: True
    """
    
    # Your code here:
    if re.search('[A-Z]', x):
        return True
    else:
        raise ValueError("The string does not contain at least one capital letter")

print(check_capital("Banana"))
print(check_capital("banana"))
# Out:
# True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-d8002cce9247> in <module>
#      20
#      21 print(check_capital("Banana"))
# ---> 22 print(check_capital("banana"))
#
# <ipython-input-37-d8002cce9247> in check_capital(x)
#      17         return True
#      18     else:
# ---> 19         raise ValueError("The string does not contain at least one capital letter")
#      20
#      21 print(check_capital("Banana"))
#
# ValueError: The string does not contain at least one capital letter

# %% [markdown]
# Examples to understand finally

# %%
def try_catch_finally():
    try:
        print("try")
        return 'success'
    except:
        raise 'fail!'
    finally:
        print('position') #que va t-il se passer ? ?
def try_catch_finally_2():
    try:
        return 'success'
    except:
        raise 'fail!'
    print('position')

# %%
try_catch_finally()
# Out:
# try
# position
# 'success'

# %%
try_catch_finally_2()
# Out:
# 'success'

# %% [markdown]
# # bonus 2

# %% [markdown]
# You’re going to write an interactive calculator!
#
# User input is assumed to be a formula that consist of a number, an operator (at least + and -), and another number, separated by white space (e.g. 1 + 1).
#
# Split user input using str.split(), and check whether the resulting list is valid:
# If the input does not consist of 3 elements, raise a FormulaError, which is a custom Exception.
#
# Try to convert the first and third input to a float (like so: float_value = float(str_value)). Catch any ValueError that occurs, and instead raise a FormulaError
#
# If the second input is not '+' or '-', again raise a FormulaError
#
# If the input is valid, perform the calculation and print out the result. The user is then prompted to provide new input, and so on, until the user enters quit.
#
# An interaction could look like this:
# >>> 1 + 1
#
# 2.0
#
# >>> 3.2 - 1.5
#
# 1.7000000000000002
#
# >>> quit
#
# print('Enter your name:')
#
# x = input()
#
# print('Hello, ' + x)

# %%
class Error(Exception):
    """Base class for exceptions in this module."""
    pass


class FormulaError(Error):
    """Exception raised for errors in the input.

    Attributes:
        expression -- input expression in which the error occurred
        message -- explanation of the error
    """

    def __init__(self, expression, message):
        self.expression = expression
        self.message = message


def calculator (calculation):
    
    # check if there are 3 elements in the string, otherwise raise an error
    if len(calculation.split()) != 3:
        raise FormulaError(calculation, "the string entered has more or less than 3 elements. For more advanced calculations, use your phone")
    
    # split the string into 3
    firstNumber, operator, secondNumber = calculation.split()
    
    # check if the first element is a number
    try:
        firstNumber = float(firstNumber)
    except:
        print(f"the first number {firstNumber} is not a number")

    # check if the second element is a number        
    try:
        secondNumber = float(secondNumber)
    except:
        print(f"the second number {secondNumber} is not a number")

    # check that the operator is an operator
    if calculation.split()[1] not in "+-*/":
        raise FormulaError(operator, f"the operator entered {operator} is not ok.")
    
    #do the calculation
    calculation = {
        "+": firstNumber + secondNumber,
        "-": firstNumber - secondNumber,
        "/": firstNumber / secondNumber,
        "*": firstNumber * secondNumber
    }
    
    return calculation[operator]

# %%
while True:
    instruction = input(">>> ")
    if instruction == "quit":
        break
    print(calculator(instruction))
# Out:
# >>> 5 + 88
# 93.0
# >>> 69 + 1
# 70.0
# >>> 70 + 2 +
# ---------------------------------------------------------------------------
# FormulaError                              Traceback (most recent call last)
# <ipython-input-78-d7fda475fbc0> in <module>
#       3     if instruction == "quit":
#       4         break
# ----> 5     print(calculator(instruction))
#
# <ipython-input-73-4b1f445bea87> in calculator(calculation)
#      21     # check if there are 3 elements in the string, otherwise raise an error
#      22     if len(calculation.split()) != 3:
# ---> 23         raise FormulaError(calculation, "the string entered has more than 3 elements. For more advanced calculations, use your phone")
#      24
#      25     # split the string into 3
#
# FormulaError: ('70 + 2 +', 'the string entered has more than 3 elements. For more advanced calculations, use your phone')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-76d070971616> in <module>
# ----> 1 a, b = [1,2,3]
#
# ValueError: too many values to unpack (expected 2)
