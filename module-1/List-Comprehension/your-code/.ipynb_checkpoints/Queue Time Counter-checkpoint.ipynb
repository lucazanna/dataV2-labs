# %% [markdown]
# # Queue Time Counter
#
# You managed to send your friend to queue for tickets in your stead, but there is a catch: he will get there only if you tell him how much that is going to take. And everybody can only take one ticket at a time, then they go back in the last position of the queue if they need more (or go home if they are fine).
#
# Each ticket takes one minutes to emit, the queue is well disciplined, Brit-style, and so it moves smoothly, with no waste of time.
#
# You will be given an array/list/vector with all the people queuing and the initial position of your buddy, so for example, knowing that your friend is in the third position (that we will consider equal to the index, 2: he is the guy that wants 3 tickets!) and the initial queue is [2, 5, 3, 4, 6].
#
# The first dude gets his ticket and the queue goes now like this [5, 3, 4, 6, 1], then [3, 4, 6, 1, 4] and so on. In the end, our buddy will be queuing for 12 minutes, true story!
#
# Build a function to compute it, resting assured that only positive integers are going to be there and you will be always given a valid index; but we also want to go to pretty popular events, so be ready for big queues with people getting plenty of tickets.

# %%
#solution
def queue(queuers,pos):
    return sum(min(queuer, queuers[pos] - (place > pos)) for place, queuer in enumerate(queuers))

# %%
#solution reformatted
def queue(queuers,pos):
    return sum(
        [min(queuer, queuers[pos] - (place > pos)) 
        for place, queuer in enumerate(queuers)]
    )

# %%
#test
print(queue([2, 5, 3, 6, 4], 0) == 6)
print(queue([2, 5, 3, 6, 4], 1) == 18)
print(queue([2, 5, 3, 6, 4], 2) == 12)
print(queue([2, 5, 3, 6, 4], 3) == 20)
print(queue([2, 5, 3, 6, 4], 4) == 17)
# Out:
# True
# True
# True
# True
# True

# %%
#understand enumerate
[f"place: {place}, queuer: {queuer}" for place, queuer in enumerate([2, 5, 3, 6, 4])]
# Out:
# ['place: 0, queuer: 2',
#  'place: 1, queuer: 5',
#  'place: 2, queuer: 3',
#  'place: 3, queuer: 6',
#  'place: 4, queuer: 4']

# %%
#understang algorithm: min(queuer, queuers[pos] - (place > pos)) 

def queueConcatenate(queuers,pos):
    return ''.join(
        [f"queuer {queuer} | queuers[pos] {queuers[pos]} | (place > pos) {(place > pos)} | queuers[pos] - (place > pos) {queuers[pos] - (place > pos)} | result {min(queuer, queuers[pos] - (place > pos)) }\n" 
        for place, queuer in enumerate(queuers)]
    )

print(queueConcatenate([2, 5, 3, 6, 4], 2))
# Out:
# queuer 2 | queuers[pos] 3 | (place > pos) False | queuers[pos] - (place > pos) 3 | result 2
# queuer 5 | queuers[pos] 3 | (place > pos) False | queuers[pos] - (place > pos) 3 | result 3
# queuer 3 | queuers[pos] 3 | (place > pos) False | queuers[pos] - (place > pos) 3 | result 3
# queuer 6 | queuers[pos] 3 | (place > pos) True | queuers[pos] - (place > pos) 2 | result 2
# queuer 4 | queuers[pos] 3 | (place > pos) True | queuers[pos] - (place > pos) 2 | result 2

# %%
#simple solution 
def queue(queuers,pos):
    #your code here
    ticketsToBuy = queuers[pos]

    time = 0
    while ticketsToBuy > 0:
      time += 1
      
      # if the first in file has more tickets to buy then he goes to the back of the list, otherwise he leaves
      if queuers[0] == 1 :
          queuers.pop(0)
      else:
          queuers.append(queuers.pop(0)-1)

      # my friend moves ahead
      if (pos == 0):
          pos = len(queuers)-1
          ticketsToBuy += -1
      else :
          pos += -1
          
    return time
