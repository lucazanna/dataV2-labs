# %%
import random

# %%
def my_function(X):
    solutions = []
    for x in range(5, X):
        for y in range(4, X):
            for z in range(3, X):
                if (x*x==y*y+z*z):
                    solutions.append([x, y, z])
    m = 0
    for solution in solutions:
        if m < max(solution):
            m = max(solution)
    return m

X = input("What is the maximal length of the triangle side? Enter a number: ")

print("The longest side possible is " + str(my_function(int(X))))
# Out:
# What is the maximal length of the triangle side? Enter a number: 17
# The longest side possible is 15

# %%
import math

# %%
import math
def my_function(X):

    check = False
    
    for x in list(range(5, X))[::-1]:
        for y in range(4, x):
            z = math.sqrt((x**2-y**2))
            if z.is_integer() and z!= 0:
                check = True
                break
        if check:
            break
    return x

# %%
my_function_LZ(20)
# Out:
# 17

# %%
[(number, my_function_LZ(number) == my_function(number)) for number in random.sample(range(5, 100), 30)]
# Out:
# [(34, True),
#  (56, True),
#  (44, True),
#  (25, True),
#  (14, True),
#  (99, True),
#  (74, True),
#  (28, True),
#  (79, True),
#  (59, True),
#  (39, True),
#  (43, True),
#  (97, True),
#  (40, True),
#  (92, True),
#  (32, True),
#  (80, True),
#  (21, True),
#  (77, True),
#  (90, True),
#  (49, True),
#  (48, True),
#  (24, True),
#  (12, True),
#  (16, True),
#  (57, True),
#  (18, True),
#  (50, True),
#  (62, True),
#  (17, True)]
